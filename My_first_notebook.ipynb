# %% [markdown]
# <a href="https://colab.research.google.com/github/aravind-shankar4/my-first-repo/blob/main/My_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hardware is a physical device that is used to run a software
software is not a physical device.
example:
hardware: RAM, Keyboard, Motherboard, hard disk
software- Google chrome, whatsapp, instagram
# Out:
#   File "/tmp/ipykernel_19845/3359574151.py", line 1
#     hardware is a physical device that uses to run a software
#                   ^
# SyntaxError: invalid syntax
